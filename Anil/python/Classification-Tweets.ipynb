# %%
import numpy as np
import pandas as pd
import sqlite3
import csv
import re
import nltk

# %%
conn = sqlite3.connect("../data/climateaction.db")

# %%
c = conn.cursor()

# %%
[row for row in c.execute('''
select name 
from sqlite_master 
where type = 'table';''')]
# Out:
# [('users',),
#  ('tweets',),
#  ('retweets',),
#  ('replies',),
#  ('favorites',),
#  ('followers',),
#  ('following',),
#  ('followers_names',),
#  ('following_names',)]

# %%
[row for row in c.execute('''
select *
from tweets
limit 10''')]
# Out:
# [(1258489984874541057,
#   '1258489984874541057',
#   'Big Oil doesn’t want us to know about its secret attempts to exploit the #COVID19 pandemic & roll back #climateaction. Join me in asking the government to reject their secret demands >>  https://act.gp/2Y9lr7v\xa0 #JustRecovery @GreenpeaceCA',
#   '1258489984874541057',
#   1588882368000,
#   '2020-05-07',
#   '22:12:48',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   1,
#   0,
#   1157061780750905344,
#   '1157061780750905344',
#   'RobertC76478857',
#   'Robert Cameron',
#   'https://twitter.com/RobertC76478857/status/1258489984874541057',
#   'GreenpeaceCA',
#   '#COVID19,#climateaction,#JustRecovery',
#   '',
#   'https://act.gp/2Y9lr7v',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   1589389289506,
#   '',
#   '',
#   ''),
#  (1258490198763229186,
#   '1258490198763229186',
#   'Are you kidding @SecBernhardt Don’t try to fool us that you love public lands, when this article lists how we must fight YOU to protect them! @SierraClub @CenterForBioDiv @defenders @Earthjustice @ExtinctCrisis #ClimateAction #resist  https://www.americanprogress.org/issues/green/news/2019/03/20/467548/13-5-million-acre-lie/\xa0… https://twitter.com/SecBernhardt/status/1258470782084268032\xa0…',
#   '1258490198763229186',
#   1588882419000,
#   '2020-05-07',
#   '22:13:39',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   1,
#   1,
#   822591136816656385,
#   '822591136816656385',
#   'lizzyloo85',
#   'Lizzyloo',
#   'https://twitter.com/lizzyloo85/status/1258490198763229186',
#   'SecBernhardt,SierraClub,CenterForBioDiv,Defenders,Earthjustice,ExtinctCrisis',
#   '#ClimateAction,#resist',
#   '',
#   'https://www.americanprogress.org/issues/green/news/2019/03/20/467548/13-5-million-acre-lie/,https://twitter.com/SecBernhardt/status/1258470782084268032',
#   '',
#   'https://twitter.com/SecBernhardt/status/1258470782084268032',
#   0,
#   '',
#   '',
#   '',
#   1589389289480,
#   '',
#   '',
#   ''),
#  (1258491431704055813,
#   '1258491431704055813',
#   'Planting trees in cities is good for people, good for the economy and an important answer to the #climatecrisis.\n\nWe have solutions. Time to ditch fossil fuels and implement them. #ActOnClimate\n#ClimateEmergency #ClimateAction #Renewables #solar #wind #tech #GreenNewDeal pic.twitter.com/WwDFQgy5uq',
#   '1258491431704055813',
#   1588882713000,
#   '2020-05-07',
#   '22:18:33',
#   'W. Europe Daylight Time',
#   '',
#   10,
#   255,
#   173,
#   15088481,
#   '15088481',
#   'MikeHudema',
#   'Mike Hudema',
#   'https://twitter.com/MikeHudema/status/1258491431704055813',
#   '',
#   '#climatecrisis,#ActOnClimate,#ClimateEmergency,#ClimateAction,#Renewables,#solar,#wind,#tech,#GreenNewDeal',
#   '',
#   '',
#   '',
#   '',
#   1,
#   '',
#   '',
#   '',
#   1589389289456,
#   '',
#   '',
#   ''),
#  (1258492013176975360,
#   '1258492013176975360',
#   'Not convinced that population isn’t an issue, but as always, like George’s piece here.  Happy to say first world folks should be reducing their baby production - but that’s a big no no too.  Big issues #ClimateAction #overpopulation #PlanetoftheHumans #consumption #growth https://twitter.com/GuardianAus/status/1258379531896881159\xa0…',
#   '1258492013176975360',
#   1588882852000,
#   '2020-05-07',
#   '22:20:52',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   0,
#   0,
#   959074261,
#   '959074261',
#   'DaCrispyLettuce',
#   'Rosie Sea',
#   'https://twitter.com/DaCrispyLettuce/status/1258492013176975360',
#   '',
#   '#ClimateAction,#overpopulation,#PlanetoftheHumans,#consumption,#growth',
#   '',
#   'https://twitter.com/GuardianAus/status/1258379531896881159',
#   '',
#   'https://twitter.com/GuardianAus/status/1258379531896881159',
#   0,
#   '',
#   '',
#   '',
#   1589389289431,
#   '',
#   '',
#   ''),
#  (1258492095100141568,
#   '1258492095100141568',
#   'Can you make a difference in the fight against climate change? Yes. \nAre policy change and massive collective action necessary to combat climate change? Yes. \n\nBoth are essential.\n\nThis is an all-hands-on deck situation. Act now and act together.\n\n#ClimateAction #NoBigOilBailout',
#   '1258492095100141568',
#   1588882871000,
#   '2020-05-07',
#   '22:21:11',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   1,
#   0,
#   1237093393534029824,
#   '1237093393534029824',
#   'CSolutionCenter',
#   'Climate Solution Center',
#   'https://twitter.com/CSolutionCenter/status/1258492095100141568',
#   '',
#   '#ClimateAction,#NoBigOilBailout',
#   '',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   1589389289411,
#   '',
#   '',
#   ''),
#  (1258492549066448896,
#   '1258492549066448896',
#   ' https://youtu.be/myGUeeofzqs\xa0\nIf only we could have great conversations like this with each other everyday.  #GoVegan #vegan\n#plantbased #ClimateAction',
#   '1258492549066448896',
#   1588882980000,
#   '2020-05-07',
#   '22:23:00',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   0,
#   1,
#   2231994344,
#   '2231994344',
#   'MyTraceElements',
#   'Too late for the Blue Pill',
#   'https://twitter.com/MyTraceElements/status/1258492549066448896',
#   '',
#   '#GoVegan,#vegan,#plantbased,#ClimateAction',
#   '',
#   'https://youtu.be/myGUeeofzqs',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   1589389289388,
#   '',
#   '',
#   ''),
#  (1258493067788562433,
#   '1258493067788562433',
#   'Glad to see my old college prof Len Ortolano continuing to speak up about the justice implications of energy & #ClimateAction decision making & reparations.\nIn the #Marshall #Islands, #nuclear policy & the #ClimateEmergency come together in a different way from the normal debate. https://twitter.com/UCBRadWatch/status/1242919806250045440\xa0…',
#   '1258493067788562433',
#   1588883103000,
#   '2020-05-07',
#   '22:25:03',
#   'W. Europe Daylight Time',
#   '',
#   1,
#   0,
#   3,
#   95292788,
#   '95292788',
#   'daisypl',
#   'Daisy P-L',
#   'https://twitter.com/daisypl/status/1258493067788562433',
#   '',
#   '#ClimateAction,#Marshall,#Islands,#nuclear,#ClimateEmergency',
#   '',
#   'https://twitter.com/UCBRadWatch/status/1242919806250045440',
#   '',
#   'https://twitter.com/UCBRadWatch/status/1242919806250045440',
#   0,
#   '',
#   '',
#   '',
#   1589389289363,
#   '',
#   '',
#   ''),
#  (1258493101099884545,
#   '1258493101099884545',
#   'Climate-Change Warnings to Philanthropy Aren’t ‘Inflammatory Rhetoric’ (Letters to the Editor) \n\nREAD MORE:  https://blog.iammarketingmedia.com/climate-change-warnings-to-philanthropy-arent-inflammatory-rhetoric-letters-to-the-editor/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter\xa0…\n#Adaptation #Antarctica #Arctic #CarbonDioxide #ClimateAction #ClimateChange #ClimateScience #climatology #Companies #Environment pic.twitter.com/r8j07rLmM7',
#   '1258493101099884545',
#   1588883111000,
#   '2020-05-07',
#   '22:25:11',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   0,
#   1,
#   226310002,
#   '226310002',
#   'IAM__Network',
#   'IAM Platform',
#   'https://twitter.com/IAM__Network/status/1258493101099884545',
#   '',
#   '#Adaptation,#Antarctica,#Arctic,#CarbonDioxide,#ClimateAction,#ClimateChange,#ClimateScience,#climatology,#Companies,#Environment',
#   '',
#   'https://blog.iammarketingmedia.com/climate-change-warnings-to-philanthropy-arent-inflammatory-rhetoric-letters-to-the-editor/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter',
#   'https://pbs.twimg.com/media/EXcQzlgWAAEf7gL.jpg',
#   '',
#   0,
#   '',
#   '',
#   '',
#   1589389289326,
#   '',
#   '',
#   ''),
#  (1258493410421477378,
#   '1258493410421477378',
#   'Big Oil doesn’t want us to know about its secret attempts to exploit the #COVID19 pandemic & roll back #climateaction. Join me in asking the government to reject their secret demands >>  https://act.gp/2Y9lr7v\xa0 #JustRecovery @GreenpeaceCA',
#   '1258493410421477378',
#   1588883185000,
#   '2020-05-07',
#   '22:26:25',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   1,
#   0,
#   156643416,
#   '156643416',
#   'katbalou42',
#   'kat balou',
#   'https://twitter.com/katbalou42/status/1258493410421477378',
#   'GreenpeaceCA',
#   '#COVID19,#climateaction,#JustRecovery',
#   '',
#   'https://act.gp/2Y9lr7v',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   1589389289302,
#   '',
#   '',
#   ''),
#  (1258493529610784768,
#   '1258493529610784768',
#   'Excited to facilitate a dialogue on behalf of the BC Climate Leadership Council hosted by @andreareimer on May 14th covering the topic of local #climateaction opportunities for economic recovery & healthy resilient communities. Join us! Register 👇\n http://communityenergy.bc.ca/upcoming-webinar-the-opportunity-of-here-and-now-local-governments-and-a-green-recovery/\xa0…',
#   '1258493529610784768',
#   1588883213000,
#   '2020-05-07',
#   '22:26:53',
#   'W. Europe Daylight Time',
#   '',
#   0,
#   1,
#   1,
#   793165825490296832,
#   '793165825490296832',
#   'bc_cea',
#   'CEA',
#   'https://twitter.com/bc_cea/status/1258493529610784768',
#   'andreareimer',
#   '#climateaction',
#   '',
#   'http://communityenergy.bc.ca/upcoming-webinar-the-opportunity-of-here-and-now-local-governments-and-a-green-recovery/',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   1589389289279,
#   '',
#   '',
#   '')]

# %%
# #climatehoax - ch

conn_ch = sqlite3.connect("../data/climateaction.db")
c_ch = conn_ch.cursor()

# %%
[row for row in c_ch.execute('''
select count(1)
from tweets''')]
# Out:
# [(3000,)]

# %%
# with open('eggs.csv', 'w', newline='') as csvfile:
#     spamwriter = csv.writer(csvfile, delimiter=' ',
#                             quotechar='|', quoting=csv.QUOTE_MINIMAL)
#     spamwriter.writerow(['Spam'] * 5 + ['Baked Beans'])
#     spamwriter.writerow(['Spam', 'Lovely Spam', 'Wonderful Spam'])
